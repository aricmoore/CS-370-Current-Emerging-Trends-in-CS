# %% [markdown]
# # CS 370 Module Two Assignment
# ---
# <div class="alert alert-block alert-success" style="color:black;">
# <b>To Begin:</b> Use this <b>LastName_FirstName_Assignment2.ipynb</b> file to complete your assignment. Look for the section header <b>Start of Rubric Graded Items</b> for the placeholders for your assignment.
# <br><br>
# <b>When Finished:</b> When you have completed your work, download the project as an HTML file and submit the HTML file. Make sure that your file is named as specified in the rubric, and that you have addressed all of the rubric criteria in your response.
# </div>
#
# <div class="alert alert-block alert-info" style="color:black;">
#     <b>Hint:</b> The code samples from the <b>Deep Learning with Keras</b> required readings pages 16-21 have been pre-loaded for you in the <b>Example_Code_Assignment2.ipynb</b> file. Some of the foundational starter code has also been added here as a starting point for your assignment as applicable.
# </div>
#
# <div class="alert alert-block alert-warning" style="color:black;">
#     <b>Note:</b> For compatability purposes, libraries have been updated from those used in the required readings to match to current versions; hence some of the package invocations may differ slightly from the book. The affected lines of code have comments added to the right as applicable, with the old code commented out above for reference.
# </div>
#
# <div class="alert alert-block alert-danger" style="color:black;">
# <b>GPU/CUDA/Memory Warnings/Errors:</b> You may receive some errors referencing that GPUs will not be used, CUDA could not be found, or free system memory allocation errors. These and a few others, are standard errors that can be ignored here as they are environment based.<br><br>
# <b>Example messages:</b>
#     <ul>
#         <li>Could not find cuda drivers on your machine, GPU will not be used.</li>
#         <li>Please check linkage and avoid linking the same target more than once.</li>
#         <li>E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)</li>
#         <li>Allocation of ######## exceeds 10% of free system memory</li>
#     </ul>
# </div>
#
# ---
#
# ## Required Baseline Starter Code
# ---
#
# ### Installing Required Packages
# This is to install necessary components to run the assignment
# <div class="alert alert-block alert-info" style="color:black;">
#     <b>Hint:</b> Ensure that you run all starter code blocks before running your code from the <b>Start of Rubric Graded Items</b> sections.
# </div>

# %%
# !pip install -r requirements.txt
# Out:
# Collecting numpy==1.26 (from -r requirements.txt (line 1))
#   Downloading numpy-1.26.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 777.6 kB/s eta 0:00:00a 0:00:01
# Collecting keras==3.10.0 (from -r requirements.txt (line 2))
#   Downloading keras-3.10.0-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: absl-py in /home/codio/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras==3.10.0->-r requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied: rich in /home/codio/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras==3.10.0->-r requirements.txt (line 2)) (13.7.1)
# Requirement already satisfied: namex in /home/codio/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras==3.10.0->-r requirements.txt (line 2)) (0.0.8)
# Requirement already satisfied: h5py in /home/codio/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras==3.10.0->-r requirements.txt (line 2)) (3.11.0)
# Requirement already satisfied: optree in /home/codio/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras==3.10.0->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: ml-dtypes in /home/codio/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras==3.10.0->-r requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: packaging in /home/codio/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras==3.10.0->-r requirements.txt (line 2)) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/codio/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from optree->keras==3.10.0->-r requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/codio/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from rich->keras==3.10.0->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/codio/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from rich->keras==3.10.0->-r requirements.txt (line 2)) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/codio/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras==3.10.0->-r requirements.txt (line 2)) (0.1.2)
# Downloading numpy-1.26.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 39.7 MB/s eta 0:00:00:00:0100:01
# Downloading keras-3.10.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 12.6 MB/s eta 0:00:0000:01
# Installing collected packages: numpy, keras
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: keras
#     Found existing installation: keras 3.4.1
#     Uninstalling keras-3.4.1:
#       Successfully uninstalled keras-3.4.1
# Successfully installed keras-3.10.0 numpy-1.26.0
#
# [notice] A new release of pip is available: 24.1.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ---
# ### Loading the Required Libraries
# <div class="alert alert-block alert-danger" style="color:black;">
# <b>Warnings:</b> As a reminder, you may receive some errors here, these are standard errors that can be ignored as they are environment based.
# </div>
#
# Potentially helpful links:
# - https://keras.io/
# - https://keras.io/api/datasets/
# - https://keras.io/api/models/
# - https://keras.io/api/layers/
# - https://keras.io/api/optimizers/
# - https://keras.io/api/utils/python_utils/

# %%
from __future__ import print_function
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
#from keras.layers.code import Dense, Activation # From the book, code replaced below
from keras.layers import Dense, Activation, Input # syntax change due to version bump
from keras.optimizers import SGD
#from keras.utils import np_utils # From the book, code replaced below
from keras.utils import to_categorical # syntax change due to version bump

# %% [markdown]
# ---
# ### Generating a Numpy Random Seed For Reproducibility
# <div class="alert alert-block alert-warning" style="color:black;">
#     <b>Note:</b> The best practice is to not reseed a BitGenerator, but rather to recreate a new one. While this method for the the seed generation is considered a legacy function, here we use it to as a way to ensure reproducible results for repeatble course submissions.
# </div>
#
# Potentially helpful links:
# - https://keras.io/api/utils/python_utils/

# %%
np.random.seed(1671) # for reproducibility

# %% [markdown]
# ---
# ### Network and Training Parameters
# <div class="alert alert-block alert-danger" style="color:black;">
# <b>Warnings:</b> As a reminder, you may receive some errors here, these are standard errors that can be ignored as they are environment based.
# </div>

# %%
NB_EPOCH = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 # number of outputs = number of digits
OPTIMIZER = SGD() # SGD optimizer, explained later in this chapter
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2 # how much TRAIN is reserved for VALIDATION
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1768357765.605629     371 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1768357765.661688     371 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1768357765.663612     371 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1768357765.666604     371 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1768357765.668358     371 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1768357765.670110     371 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1768357765.869274     371 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1768357765.871062     371 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1768357765.872641     371 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %% [markdown]
# ---
# ### Spliting Data Into Train and Test Sets

# %%
# data: shuffled and split between train and test sets
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# ---
# ### Shaping

# %%
# X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784

RESHAPED = 784

X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
# normalize
X_train /= 255
X_test /= 255

print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# 60000 train samples
# 10000 test samples

# %%
# convert class vectors to binary class matrices

# Y_train = np_utils.to_categorical(y_train, NB_CLASSES) # From the book, code replaced below
Y_train = to_categorical(y_train, NB_CLASSES) # Updated for current version

#Y_test = np_utils.to_categorical(y_test, NB_CLASSES) # From the book, code replaced below
Y_test = to_categorical(y_test, NB_CLASSES) # Updated for current version

# %% [markdown]
# ---
# # Start of Rubric Graded Items
# ---
# <div class="alert alert-block alert-success" style="color:black;">
# <b>To Begin:</b> Once you have reviewed the output of the blocks above, use the blocks below to complete your assignment portions.
# </div>
#
# <div class="alert alert-block alert-info" style="color:black;">
#     <b>Hint:</b> As a reminder, the code samples from the <b>Deep Learning with Keras</b> required readings pages 16-21 have been pre-loaded for you in the <b>Example_Code_Assignment2.ipynb</b> file. Some of the foundational starter code has also been added here as a starting point for your assignment as applicable in the cells above.
# </div>
#
# ---
#
# ## Notebook Configuration and Naming Convention
# Click on LastName_FirstName_Assignment2.ipynb in the filetree and rename it following that convention. For example, if your name is Jane Doe, you would rename the file Doe_Jane_Assignment2.ipynb for later submission.
#
# ---
# ## Establishes Accuracy Scores with Two Hidden Layers
# Follow the examples in the book to establish an accuracy rate for the training, validation, and test data sets with two hidden layers.
#
#
# <div class="alert alert-block alert-warning" style="color:black;">
#     <b>Note:</b> The example model configurations provided below must be modified for your assignment submission. Some lines are standard commands.
# </div>
#
# <div class="alert alert-block alert-info" style="color:black;">
# <b>Hint:</b> Read through the MNIST handwritten digits example on pages 16-24 of <b>Deep Learning with Keras</b>. The code from pages 16-18 have been copied over to this Jupyter Notebook file for you as applicable in the cells above above for the minimum required baseline code. The hidden layers examples are provided starting on page 22, ensure to keep example modifications from above in mind when building out the rest of your assignment code blocks. The code below can be copied and used to start building out your hidden layers task.
# <br><br>
# <div style="background:#eff0f1;padding-left:10px">
# <code style="margin-left:-5px"><b>Book Example Code Snippet: A simple neural net in Keras</b>
# # 10 outputs
# # final stage is softmax
# model = Sequential()
# # model.add(Dense(NB_CLASSES, input_shape=(RESHAPED,))) # From the book, code replaced below
# model.add(Input(shape=(RESHAPED,))) # Updated for current version
# model.add(Dense(NB_CLASSES)) # Updated for current version
# model.add(Activation('softmax'))
# model.summary()
# model.compile(loss='categorical_crossentropy', optimizer=OPTIMIZER, metrics=['accuracy'])
# history = model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=NB_EPOCH, verbose=VERBOSE,
# validation_split=VALIDATION_SPLIT)
# score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
# print("Test Score:", score[0])
# print("Test Accuracy:", score[1])
# </code>
# </div>
# </div>
#
# <div class="alert alert-block alert-danger" style="color:black;">
# <b>Warnings:</b> As a reminder, you may receive some errors in the model here, these are standard errors that can be ignored as they are environment based.
# </div>
#
# Potentially helpful links:
# - https://keras.io/api/models/sequential/
# - https://keras.io/api/layers/activations/
# - https://keras.io/api/models/sequential/#add-method
# - https://keras.io/api/layers/
# - https://keras.io/api/layers/core_layers/
# - https://keras.io/api/models/model_training_apis/#compile-method
# - https://keras.io/api/models/model_training_apis/#fit-method
# - https://keras.io/api/models/model_training_apis/#evaluate-method

# %% [markdown]
# ---
# ## Establishes Accuracy Scores by Varying Parameters
# Pick one parameter and run two or three different experiments modifying the parameter values to establish accuracy scores with different parameter values. Make sure the experiments result in significant changes in accuracy rates. Be sure to place each experiment in a different code block so that your instructor can view all of your changes.
#
# <div class="alert alert-block alert-warning" style="color:black;">
#     <b>Note:</b> You may have to do some research beyond the information provided in the book to implement these changes. Remember to copy your model definition, compilation, training, and evaluation blocks to test your experiment.
# </div>
#
# <div class="alert alert-block alert-info" style="color:black;">
# <b>Hint:</b> Sample parameters that you can overwrite here were used in the <b>Network and Training Parameters</b> section above. This is not all inclusive and just provided as a baseline. See the additional example parameters starting on page 25 in the <b>Deep Learning with Keras</b> book.
# <br><br><b>Important:</b> When codifying your experiements, ensure that you include the replacement variable in the cell below, followed by the hidden layers code you developed in the rubric item above.<br><br>
# <div style="background:#eff0f1;padding-left:10px">
# <code style="margin-left:-5px"><b>Book Example Code Snippet: Copied from cell above for quick reference to variable naming</b>
# NB_EPOCH = 20
# BATCH_SIZE = 128
# VERBOSE = 1
# NB_CLASSES = 10 # number of outputs = number of digits
# OPTIMIZER = SGD() # SGD optimizer, explained later in this chapter
# N_HIDDEN = 128
# VALIDATION_SPLIT = 0.2 # how much TRAIN is reserved for VALIDATION
# </code>
# </div>
# </div>
#
# Potentially helpful links:
# - https://keras.io/api/models/model_training_apis/#fit-method
#
# ### Experiment 1
#
# <div class="alert alert-block alert-info" style="color:black;">
# <b>Hint:</b> When modifying parameters that will impact the optimization of the solution, ensure that you add the <b>OPTIMIZER = SGD()</b> line before your code with the hidden layers from above.
# </div>

# %%
# Experiment 1: Increases hidden neurons from 128 to 256
N_HIDDEN = 256
OPTIMIZER = SGD()

# Defines model
model = Sequential()
model.add(Input(shape=(RESHAPED,)))
model.add(Dense(N_HIDDEN, activation='relu'))
model.add(Dense(N_HIDDEN, activation='relu'))
model.add(Dense(NB_CLASSES, activation='softmax'))
model.summary()

# Compiles model
model.compile(loss='categorical_crossentropy', optimizer=OPTIMIZER, metrics=['accuracy'])

# Trains model
history = model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=NB_EPOCH, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

# Evaluates model
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 269,322 (1.03 MB)
#  Trainable params: 269,322 (1.03 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1768358624.092690    1164 service.cc:146] XLA service 0x70c534014e70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1768358624.092725    1164 service.cc:154]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
#  94/375 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2005 - loss: 2.2221
# I0000 00:00:1768358624.764327    1164 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4730 - loss: 1.8376 - val_accuracy: 0.8527 - val_loss: 0.6886
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8491 - loss: 0.6278 - val_accuracy: 0.8882 - val_loss: 0.4336
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8827 - loss: 0.4397 - val_accuracy: 0.9002 - val_loss: 0.3634
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8982 - loss: 0.3687 - val_accuracy: 0.9085 - val_loss: 0.3267
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9048 - loss: 0.3372 - val_accuracy: 0.9146 - val_loss: 0.3042
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9117 - loss: 0.3136 - val_accuracy: 0.9182 - val_loss: 0.2877
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9169 - loss: 0.2963 - val_accuracy: 0.9215 - val_loss: 0.2759
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9185 - loss: 0.2835 - val_accuracy: 0.9246 - val_loss: 0.2635
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9243 - loss: 0.2679 - val_accuracy: 0.9271 - val_loss: 0.2520
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9275 - loss: 0.2610 - val_accuracy: 0.9304 - val_loss: 0.2432
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9298 - loss: 0.2490 - val_accuracy: 0.9312 - val_loss: 0.2358
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9315 - loss: 0.2392 - val_accuracy: 0.9349 - val_loss: 0.2287
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9336 - loss: 0.2308 - val_accuracy: 0.9361 - val_loss: 0.2214
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9361 - loss: 0.2256 - val_accuracy: 0.9396 - val_loss: 0.2152
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9390 - loss: 0.2157 - val_accuracy: 0.9408 - val_loss: 0.2101
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9407 - loss: 0.2097 - val_accuracy: 0.9427 - val_loss: 0.2047
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9444 - loss: 0.1978 - val_accuracy: 0.9442 - val_loss: 0.1994
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9421 - loss: 0.1993 - val_accuracy: 0.9460 - val_loss: 0.1942
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9478 - loss: 0.1900 - val_accuracy: 0.9473 - val_loss: 0.1902
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9473 - loss: 0.1857 - val_accuracy: 0.9485 - val_loss: 0.1856
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9388 - loss: 0.2113
# Test Score: 0.18233443796634674
# Test Accuracy: 0.9472000002861023

# %% [markdown]
# ### Experiment 2
# <div class="alert alert-block alert-info" style="color:black;">
# <b>Hint:</b> When modifying parameters that will impact the optimization of the solution, ensure that you add the <b>OPTIMIXER = SGD()</b> line before your code with the hidden layers from above.
# </div>

# %%
# Experiment 2: Increases batch size from 128 to 256
BATCH_SIZE = 256
N_HIDDEN = 128  # Reset to baseline for comparison
OPTIMIZER = SGD()

# Defines model
model = Sequential()
model.add(Input(shape=(RESHAPED,)))
model.add(Dense(N_HIDDEN, activation='relu'))
model.add(Dense(N_HIDDEN, activation='relu'))
model.add(Dense(NB_CLASSES, activation='softmax'))
model.summary()

# Compiles model
model.compile(loss='categorical_crossentropy', optimizer=OPTIMIZER, metrics=['accuracy'])

# Trains model
history = model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=NB_EPOCH, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

# Evaluates model
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 118,282 (462.04 KB)
#  Trainable params: 118,282 (462.04 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.3207 - loss: 2.0842 - val_accuracy: 0.7540 - val_loss: 1.2676
# Epoch 2/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7752 - loss: 1.0890 - val_accuracy: 0.8457 - val_loss: 0.6820
# Epoch 3/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8392 - loss: 0.6655 - val_accuracy: 0.8742 - val_loss: 0.5101
# Epoch 4/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8657 - loss: 0.5171 - val_accuracy: 0.8878 - val_loss: 0.4338
# Epoch 5/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8798 - loss: 0.4499 - val_accuracy: 0.8945 - val_loss: 0.3908
# Epoch 6/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8908 - loss: 0.4011 - val_accuracy: 0.9003 - val_loss: 0.3623
# Epoch 7/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8943 - loss: 0.3802 - val_accuracy: 0.9053 - val_loss: 0.3419
# Epoch 8/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9005 - loss: 0.3570 - val_accuracy: 0.9079 - val_loss: 0.3270
# Epoch 9/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9040 - loss: 0.3391 - val_accuracy: 0.9104 - val_loss: 0.3156
# Epoch 10/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9079 - loss: 0.3237 - val_accuracy: 0.9131 - val_loss: 0.3054
# Epoch 11/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9101 - loss: 0.3138 - val_accuracy: 0.9153 - val_loss: 0.2967
# Epoch 12/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9116 - loss: 0.3076 - val_accuracy: 0.9171 - val_loss: 0.2891
# Epoch 13/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9149 - loss: 0.2979 - val_accuracy: 0.9192 - val_loss: 0.2817
# Epoch 14/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9153 - loss: 0.2904 - val_accuracy: 0.9200 - val_loss: 0.2761
# Epoch 15/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9175 - loss: 0.2872 - val_accuracy: 0.9218 - val_loss: 0.2700
# Epoch 16/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9214 - loss: 0.2755 - val_accuracy: 0.9239 - val_loss: 0.2646
# Epoch 17/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9212 - loss: 0.2714 - val_accuracy: 0.9250 - val_loss: 0.2601
# Epoch 18/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9255 - loss: 0.2637 - val_accuracy: 0.9277 - val_loss: 0.2546
# Epoch 19/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9239 - loss: 0.2690 - val_accuracy: 0.9282 - val_loss: 0.2513
# Epoch 20/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9271 - loss: 0.2579 - val_accuracy: 0.9297 - val_loss: 0.2469
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9206 - loss: 0.2817
# Test Score: 0.2436419129371643
# Test Accuracy: 0.9319999814033508

# %% [markdown]
# ### Experiment 3 (Optional)
# <div class="alert alert-block alert-info" style="color:black;">
# <b>Hint:</b> When modifying parameters that will impact the optimization of the solution, ensure that you add the <b>OPTIMIZER = SGD()</b> line before your code with the hidden layers from above.
# </div>

# %%
# Experiment 3: Reduces epochs from 20 to 10
NB_EPOCH = 10
BATCH_SIZE = 128  # Reset to baseline
N_HIDDEN = 128
OPTIMIZER = SGD()

# Defines model
model = Sequential()
model.add(Input(shape=(RESHAPED,)))
model.add(Dense(N_HIDDEN, activation='relu'))
model.add(Dense(N_HIDDEN, activation='relu'))
model.add(Dense(NB_CLASSES, activation='softmax'))
model.summary()

# Compiles model
model.compile(loss='categorical_crossentropy', optimizer=OPTIMIZER, metrics=['accuracy'])

# Trains model
history = model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=NB_EPOCH, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

# Evaluates model
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 118,282 (462.04 KB)
#  Trainable params: 118,282 (462.04 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4701 - loss: 1.8560 - val_accuracy: 0.8428 - val_loss: 0.7341
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8492 - loss: 0.6542 - val_accuracy: 0.8848 - val_loss: 0.4480
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8798 - loss: 0.4538 - val_accuracy: 0.8978 - val_loss: 0.3745
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8939 - loss: 0.3832 - val_accuracy: 0.9052 - val_loss: 0.3376
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9022 - loss: 0.3467 - val_accuracy: 0.9127 - val_loss: 0.3123
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9067 - loss: 0.3319 - val_accuracy: 0.9158 - val_loss: 0.2956
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9123 - loss: 0.3070 - val_accuracy: 0.9197 - val_loss: 0.2844
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9137 - loss: 0.2970 - val_accuracy: 0.9219 - val_loss: 0.2734
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9171 - loss: 0.2846 - val_accuracy: 0.9254 - val_loss: 0.2616
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9202 - loss: 0.2731 - val_accuracy: 0.9282 - val_loss: 0.2529
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9139 - loss: 0.2961
# Test Score: 0.25646477937698364
# Test Accuracy: 0.9261999726295471

# %% [markdown]
# ---
# ## Explains Changes in Accuracy Rates
# Create a Markdown cell in your Jupyter Notebook after your code and its outputs.
# In this cell, explain the changes in accuracy rates by comparing and contrasting your results from Steps 3 and 4. What happens to the accuracy rates for the training, validation, and test data sets as you change the parameters. Why?
#
# <div class="alert alert-block alert-info" style="color:black;">
#     <b>Hint:</b> To use the markdown block below, double click in the <b>Type Markdown and LaTeX:  𝛼2</b> block below, to turn it back to html, Run the cell.
# </div>
#
# Potentially helpful links:
# - https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html

# %% [markdown]
# The purpose of these experiments is to explore the effect of modifying network parameters on the model's ability to recognize digits from the MNIST dataset.
#
# Experiment #1:
# I used two hidden layers with 256 neurons each. This experiment achieved the highest level of accuracy with approximately 94.7% on the test set. Validation and test performance were improved due to the increased number of neurons, enabling the model to capture more complex patterns in the training data.
#
# Experiment #2:
# This experiment reduced hidden layers to 128 neurons each, reducing the network's capacity to learn complex features and resulting in a slightly lower test accuracy score of approximately 93.2%. Although the model still generalizes well to the unseen data, this experiment demonstrates that decreasing network size has a slight impact on performance.
#
# Experiment #3:
# Reducing the number of epochs from 20 to 10 limited the training time within the network, meaning that the model didn't fully converge, which led to a slightly lower accuracy of approximately 92.6% compared to Experiment 2. Even when the network size remains the same, this confirms that sufficient epochs are necessary for the network to effectively learn the patterns in the dataset.
